# %%
# %%HTML
# <style> code {background-color : pink !important;} </style>
# Out:
# <style> code {background-color : pink !important;} </style>

# %% [markdown]
# Camera Calibration with OpenCV
# ===
#
# ### Run the code in the cell below to extract object points and image points for camera calibration.

# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
#%matplotlib qt

# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*8,3), np.float32)
objp[:,:2] = np.mgrid[0:8, 0:6].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d points in real world space
imgpoints = [] # 2d points in image plane.

# Make a list of calibration images
images = glob.glob('calibration_wide/GO*.jpg')

# Step through the list and search for chessboard corners
for idx, fname in enumerate(images):
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (8,6), None)

    # If found, add object points, image points
    if ret == True:
        objpoints.append(objp)
        imgpoints.append(corners)

        # Draw and display the corners
        cv2.drawChessboardCorners(img, (8,6), corners, ret)
        #write_name = 'corners_found'+str(idx)+'.jpg'
        #cv2.imwrite(write_name, img)
        cv2.imshow('img', img)
        cv2.waitKey(500)

cv2.destroyAllWindows()

# %% [markdown]
# ### If the above cell ran sucessfully, you should now have `objpoints` and `imgpoints` needed for camera calibration.  Run the cell below to calibrate, calculate distortion coefficients, and test undistortion on an image!

# %%
def calibrate_and_undistort(img, img_points, obj_points):
    """
    Finds the paramters required for calibrating the camera and returns undistorted images
    args:
    - img [array]: Image array of size WxHXD
    - obj_points [array[arrays]]: 3D points in real world corresponding to the points in the image plane
    - img_points [array[arrays]]: 2D points in the image plane
    returns:
    - undistort [array]: Undistorted image array 
    - cam_matrix [array]: Camera matrix with intrinsic parameters
    - distort_coeff [array]: Distortion Coefficients of the images
    """
    img_shape = img.shape[1::-1]
    ret, cam_matrix, distort_coeff, rvec, tvec = cv2.calibrateCamera(objpoints,
                                                                     imgpoints, 
                                                                     img_shape, 
                                                                     None, None)
    undist = cv2.undistort(img, cam_matrix, distort_coeff, None, cam_matrix)
    return undist, cam_matrix, distort_coeff

# %%
import pickle
# %matplotlib inline

# Test undistortion on an image
img = cv2.imread('calibration_wide/test_image.jpg')
img_size = (img.shape[1], img.shape[0])

# Do camera calibration given object points and image points
undist, cam_matrix, distortion_coeff = calibrate_and_undistort(img, imgpoints, objpoints)
cv2.imwrite('calibration_wide/test_undist.jpg',undist)

# Save the camera calibration result for later use (we won't worry about rvecs / tvecs)
dist_pickle = {}
dist_pickle["mtx"] = cam_matrix
dist_pickle["dist"] = distortion_coeff
pickle.dump( dist_pickle, open( "calibration_wide/wide_dist_pickle.p", "wb" ) )
#dst = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
# Visualize undistortion
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(undist)
ax2.set_title('Undistorted Image', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Undistorted Image')
